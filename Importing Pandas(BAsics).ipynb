# %%
import pandas as pd

# %%
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
    age.append(random.randint(0,100))
    height.append(random.randint(0,100))
    weight.append(random.randint(0,100))
    speed.append(random.randint(0,100))
idata={'Age': age, 'Height': height, 'Weight': weight, 'Speed': speed}
idata
# Out:
# {'Age': [57,
#   9,
#   15,
#   95,
#   47,
#   17,
#   9,
#   79,
#   24,
#   59,
#   37,
#   91,
#   87,
#   65,
#   49,
#   89,
#   39,
#   82,
#   53,
#   61,
#   38,
#   87,
#   95,
#   75,
#   72,
#   14,
#   21,
#   19,
#   20,
#   59,
#   81,
#   26,
#   14,
#   57,
#   6,
#   91,
#   55,
#   10,
#   51,
#   68,
#   9,
#   75,
#   37,
#   96,
#   9,
#   3,
#   69,
#   91,
#   6,
#   14,
#   87,
#   62,
#   33,
#   60,
#   25,
#   35,
#   97,
#   85,
#   72,
#   36,
#   73,
#   32,
#   66,
#   97,
#   93,
#   67,
#   51,
#   31,
#   89,
#   61,
#   30,
#   50,
#   88,
#   35,
#   7,
#   46,
#   59,
#   24,
#   75,
#   19,
#   95,
#   1,
#   14,
#   51,
#   62,
#   24,
#   23,
#   82,
#   34,
#   47,
#   34,
#   97,
#   74,
#   28,
#   23,
#   18,
#   67,
#   8,
#   95,
#   15],
#  'Height': [43,
#   37,
#   96,
#   16,
#   21,
#   10,
#   97,
#   73,
#   32,
#   25,
#   80,
#   19,
#   64,
#   29,
#   77,
#   15,
#   1,
#   37,
#   87,
#   72,
#   8,
#   43,
#   83,
#   20,
#   75,
#   58,
#   58,
#   7,
#   94,
#   35,
#   25,
#   28,
#   92,
#   8,
#   71,
#   38,
#   73,
#   93,
#   62,
#   12,
#   79,
#   75,
#   1,
#   4,
#   89,
#   56,
#   85,
#   59,
#   58,
#   78,
#   63,
#   95,
#   19,
#   19,
#   83,
#   30,
#   9,
#   86,
#   36,
#   37,
#   46,
#   64,
#   41,
#   50,
#   26,
#   13,
#   33,
#   51,
#   56,
#   29,
#   49,
#   41,
#   90,
#   62,
#   31,
#   77,
#   61,
#   39,
#   97,
#   2,
#   38,
#   73,
#   58,
#   88,
#   16,
#   46,
#   46,
#   44,
#   85,
#   12,
#   56,
#   9,
#   28,
#   85,
#   71,
#   60,
#   38,
#   2,
#   28,
#   90],
#  'Weight': [100,
#   97,
#   31,
#   20,
#   93,
#   36,
#   24,
#   12,
#   43,
#   86,
#   58,
#   25,
#   32,
#   42,
#   71,
#   94,
#   3,
#   73,
#   91,
#   58,
#   31,
#   28,
#   38,
#   55,
#   78,
#   69,
#   21,
#   38,
#   14,
#   81,
#   81,
#   76,
#   83,
#   69,
#   11,
#   100,
#   80,
#   63,
#   23,
#   76,
#   99,
#   97,
#   58,
#   56,
#   100,
#   7,
#   31,
#   80,
#   62,
#   30,
#   57,
#   72,
#   81,
#   46,
#   31,
#   35,
#   52,
#   41,
#   79,
#   1,
#   54,
#   47,
#   8,
#   71,
#   11,
#   71,
#   76,
#   95,
#   63,
#   48,
#   66,
#   17,
#   20,
#   35,
#   49,
#   57,
#   18,
#   68,
#   11,
#   44,
#   67,
#   51,
#   46,
#   56,
#   92,
#   54,
#   3,
#   43,
#   20,
#   16,
#   68,
#   82,
#   47,
#   82,
#   32,
#   79,
#   69,
#   6,
#   64,
#   33],
#  'Speed': [39,
#   58,
#   64,
#   45,
#   28,
#   26,
#   50,
#   84,
#   3,
#   81,
#   65,
#   39,
#   29,
#   32,
#   44,
#   33,
#   97,
#   47,
#   26,
#   100,
#   84,
#   89,
#   87,
#   12,
#   99,
#   90,
#   58,
#   33,
#   78,
#   49,
#   36,
#   39,
#   89,
#   89,
#   7,
#   36,
#   2,
#   97,
#   31,
#   79,
#   21,
#   48,
#   74,
#   55,
#   25,
#   62,
#   17,
#   76,
#   2,
#   54,
#   30,
#   25,
#   23,
#   9,
#   64,
#   33,
#   55,
#   96,
#   52,
#   16,
#   3,
#   90,
#   86,
#   16,
#   80,
#   58,
#   25,
#   76,
#   39,
#   74,
#   75,
#   50,
#   67,
#   59,
#   77,
#   7,
#   70,
#   35,
#   94,
#   79,
#   10,
#   20,
#   47,
#   83,
#   93,
#   19,
#   49,
#   38,
#   71,
#   43,
#   44,
#   5,
#   40,
#   42,
#   39,
#   74,
#   14,
#   100,
#   25,
#   10]}

# %%
df1=pd.DataFrame(idata)
df1
# Out:
#     Age  Height  Weight  Speed
# 0    57      43     100     39
# 1     9      37      97     58
# 2    15      96      31     64
# 3    95      16      20     45
# 4    47      21      93     28
# ..  ...     ...     ...    ...
# 95   18      60      79     74
# 96   67      38      69     14
# 97    8       2       6    100
# 98   95      28      64     25
# 99   15      90      33     10
#
# [100 rows x 4 columns]

# %%
df1.tail(10)
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    50.090000   49.060000   52.580000   50.370000
# std     29.520099   28.435225   27.574758   28.419887
# min      1.000000    1.000000    1.000000    2.000000
# 25%     23.750000   27.500000   31.000000   27.500000
# 50%     51.000000   46.000000   54.500000   47.500000
# 75%     75.000000   73.500000   76.000000   76.000000
# max     97.000000   97.000000  100.000000  100.000000

# %%
df1["Age"]
# Out:
# 0     57
# 1      9
# 2     15
# 3     95
# 4     47
#       ..
# 95    18
# 96    67
# 97     8
# 98    95
# 99    15
# Name: Age, Length: 100, dtype: int64

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    57      43
# 1     9      37
# 2    15      96
# 3    95      16
# 4    47      21
# ..  ...     ...
# 95   18      60
# 96   67      38
# 97    8       2
# 98   95      28
# 99   15      90
#
# [100 rows x 2 columns]

# %%
df1.loc[0:3,['Age', 'Height']]
# Out:
#    Age  Height
# 0   57      43
# 1    9      37
# 2   15      96
# 3   95      16

# %%
df2=df1[['Age','Height']]
df2.describe()
# Out:
#               Age      Height
# count  100.000000  100.000000
# mean    50.090000   49.060000
# std     29.520099   28.435225
# min      1.000000    1.000000
# 25%     23.750000   27.500000
# 50%     51.000000   46.000000
# 75%     75.000000   73.500000
# max     97.000000   97.000000

# %%
df1.sort_index()
# Out:
#     Age  Height  Weight  Speed
# 0    57      43     100     39
# 1     9      37      97     58
# 2    15      96      31     64
# 3    95      16      20     45
# 4    47      21      93     28
# ..  ...     ...     ...    ...
# 95   18      60      79     74
# 96   67      38      69     14
# 97    8       2       6    100
# 98   95      28      64     25
# 99   15      90      33     10
#
# [100 rows x 4 columns]

# %%
df1.sort_index(ascending=False)
# Out:
#     Age  Height  Weight  Speed
# 99   15      90      33     10
# 98   95      28      64     25
# 97    8       2       6    100
# 96   67      38      69     14
# 95   18      60      79     74
# ..  ...     ...     ...    ...
# 4    47      21      93     28
# 3    95      16      20     45
# 2    15      96      31     64
# 1     9      37      97     58
# 0    57      43     100     39
#
# [100 rows x 4 columns]

# %%
df1.sort_index(ascending=True)
# Out:
#     Age  Height  Weight  Speed
# 0    57      43     100     39
# 1     9      37      97     58
# 2    15      96      31     64
# 3    95      16      20     45
# 4    47      21      93     28
# ..  ...     ...     ...    ...
# 95   18      60      79     74
# 96   67      38      69     14
# 97    8       2       6    100
# 98   95      28      64     25
# 99   15      90      33     10
#
# [100 rows x 4 columns]

# %%
df2[0::2]
# Out:
#     Age  Height
# 0    57      43
# 2    15      96
# 4    47      21
# 6     9      97
# 8    24      32
# 10   37      80
# 12   87      64
# 14   49      77
# 16   39       1
# 18   53      87
# 20   38       8
# 22   95      83
# 24   72      75
# 26   21      58
# 28   20      94
# 30   81      25
# 32   14      92
# 34    6      71
# 36   55      73
# 38   51      62
# 40    9      79
# 42   37       1
# 44    9      89
# 46   69      85
# 48    6      58
# 50   87      63
# 52   33      19
# 54   25      83
# 56   97       9
# 58   72      36
# 60   73      46
# 62   66      41
# 64   93      26
# 66   51      33
# 68   89      56
# 70   30      49
# 72   88      90
# 74    7      31
# 76   59      61
# 78   75      97
# 80   95      38
# 82   14      58
# 84   62      16
# 86   23      46
# 88   34      85
# 90   34      56
# 92   74      28
# 94   23      71
# 96   67      38
# 98   95      28

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    57      43     100     39
# 1     9      37      97     58
# 2    15      96      31     64
# 3    95      16      20     45
# 4    47      21      93     28
# ..  ...     ...     ...    ...
# 95   18      60      79     74
# 96   67      38      69     14
# 97    8       2       6    100
# 98   95      28      64     25
# 99   15      90      33     10
#
# [100 rows x 4 columns]

# %%
df2[0::2].describe()
# Out:
#              Age     Height
# count  50.000000  50.000000
# mean   49.320000  55.100000
# std    29.131258  28.011113
# min     6.000000   1.000000
# 25%    23.250000  32.250000
# 50%    50.000000  58.000000
# 75%    72.750000  79.750000
# max    97.000000  97.000000

# %%
#to see set of elements weight>50
#filter
filter1=df1['Weight']>50
filter1
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
#       ...
# 95     True
# 96     True
# 97    False
# 98     True
# 99    False
# Name: Weight, Length: 100, dtype: bool

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 0    57      43     100     39
# 1     9      37      97     58
# 4    47      21      93     28
# 9    59      25      86     81
# 10   37      80      58     65
# 14   49      77      71     44
# 15   89      15      94     33
# 17   82      37      73     47
# 18   53      87      91     26
# 19   61      72      58    100
# 23   75      20      55     12
# 24   72      75      78     99
# 25   14      58      69     90
# 29   59      35      81     49
# 30   81      25      81     36
# 31   26      28      76     39
# 32   14      92      83     89
# 33   57       8      69     89
# 35   91      38     100     36
# 36   55      73      80      2
# 37   10      93      63     97
# 39   68      12      76     79
# 40    9      79      99     21
# 41   75      75      97     48
# 42   37       1      58     74
# 43   96       4      56     55
# 44    9      89     100     25
# 47   91      59      80     76
# 48    6      58      62      2
# 50   87      63      57     30
# 51   62      95      72     25
# 52   33      19      81     23
# 56   97       9      52     55
# 58   72      36      79     52
# 60   73      46      54      3
# 63   97      50      71     16
# 65   67      13      71     58
# 66   51      33      76     25
# 67   31      51      95     76
# 68   89      56      63     39
# 70   30      49      66     75
# 75   46      77      57      7
# 77   24      39      68     35
# 80   95      38      67     10
# 81    1      73      51     20
# 83   51      88      56     83
# 84   62      16      92     93
# 85   24      46      54     19
# 90   34      56      68     44
# 91   97       9      82      5
# 93   28      85      82     42
# 95   18      60      79     74
# 96   67      38      69     14
# 98   95      28      64     25

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 0    57      43     100     39
# 1     9      37      97     58
# 4    47      21      93     28
# 9    59      25      86     81
# 10   37      80      58     65
# 14   49      77      71     44
# 15   89      15      94     33
# 17   82      37      73     47
# 18   53      87      91     26
# 19   61      72      58    100
# 23   75      20      55     12
# 24   72      75      78     99
# 25   14      58      69     90
# 29   59      35      81     49
# 30   81      25      81     36
# 31   26      28      76     39
# 32   14      92      83     89
# 33   57       8      69     89
# 35   91      38     100     36
# 36   55      73      80      2
# 37   10      93      63     97
# 39   68      12      76     79
# 40    9      79      99     21
# 41   75      75      97     48
# 42   37       1      58     74
# 43   96       4      56     55
# 44    9      89     100     25
# 47   91      59      80     76
# 48    6      58      62      2
# 50   87      63      57     30
# 51   62      95      72     25
# 52   33      19      81     23
# 56   97       9      52     55
# 58   72      36      79     52
# 60   73      46      54      3
# 63   97      50      71     16
# 65   67      13      71     58
# 66   51      33      76     25
# 67   31      51      95     76
# 68   89      56      63     39
# 70   30      49      66     75
# 75   46      77      57      7
# 77   24      39      68     35
# 80   95      38      67     10
# 81    1      73      51     20
# 83   51      88      56     83
# 84   62      16      92     93
# 85   24      46      54     19
# 90   34      56      68     44
# 91   97       9      82      5
# 93   28      85      82     42
# 95   18      60      79     74
# 96   67      38      69     14
# 98   95      28      64     25

# %%
filter2=df1['Age']>50
filter2
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 95    False
# 96     True
# 97    False
# 98     True
# 99    False
# Name: Age, Length: 100, dtype: bool

# %%
df1.loc[filter1& filter2]
# Out:
#     Age  Height  Weight  Speed
# 0    57      43     100     39
# 9    59      25      86     81
# 15   89      15      94     33
# 17   82      37      73     47
# 18   53      87      91     26
# 19   61      72      58    100
# 23   75      20      55     12
# 24   72      75      78     99
# 29   59      35      81     49
# 30   81      25      81     36
# 33   57       8      69     89
# 35   91      38     100     36
# 36   55      73      80      2
# 39   68      12      76     79
# 41   75      75      97     48
# 43   96       4      56     55
# 47   91      59      80     76
# 50   87      63      57     30
# 51   62      95      72     25
# 56   97       9      52     55
# 58   72      36      79     52
# 60   73      46      54      3
# 63   97      50      71     16
# 65   67      13      71     58
# 66   51      33      76     25
# 68   89      56      63     39
# 80   95      38      67     10
# 83   51      88      56     83
# 84   62      16      92     93
# 91   97       9      82      5
# 96   67      38      69     14
# 98   95      28      64     25
